# %% [markdown]
# Text Cleaning
#
# By: Josh Navarro
#
# Goal: Learn how apply text cleaning in Jupyter Notebook using the python pandas
#
# Data: Synthesized by ChatGpt

# %%
# Imports that we are going to be using
import pandas as pd

# %%
# Synthetic Data created by ChatGPT
df = pd.DataFrame({
    "customer_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": [
        "  alex johnson ",
        "MARIA   GARCIA",
        "James-smith",
        "sofia o'neill",
        "DANIEL  lee ",
        " emma_watson",
        "Chris Brown  ",
        "mia   davis"
    ],
    "email": [
        " ALEX.JOHNSON@GMAIL.COM ",
        "maria_garcia@yahoo.com",
        "James.Smith@Outlook.COM",
        "sofia.oneill@gmail.com ",
        "daniel.lee@@gmail.com",
        "emma_watson@gmail",
        "chris.brown@hotmail.com",
        " mia.davis@gmail.com"
    ],
    "phone": [
        "(555) 123-4567",
        "555.987.6543",
        "555-222-3333",
        " 555 444 5555 ",
        "+1-555-777-8888",
        "phone: 5556669999",
        "N/A",
        "(555)-000-1111"
    ],
    "city": [
        " new york",
        "LOS ANGELES ",
        "San   Diego",
        "chicago",
        " HOUSTON",
        "phoenix!!!",
        "Dallas?",
        "san jose "
    ],
    "review": [
        "  Great product!!! ",
        "BAD service...",
        "okay-quality, not bad",
        "I LOVE this item!!!",
        "too expensive $$$",
        "would buy again :)",
        "N/A",
        "fast shipping--thanks!"
    ]
})

df
# Out:
#    customer_id             name                     email              phone  \
# 0          101    alex johnson    ALEX.JOHNSON@GMAIL.COM      (555) 123-4567
# 1          102   MARIA   GARCIA    maria_garcia@yahoo.com       555.987.6543
# 2          103      James-smith   James.Smith@Outlook.COM       555-222-3333
# 3          104    sofia o'neill   sofia.oneill@gmail.com       555 444 5555
# 4          105     DANIEL  lee      daniel.lee@@gmail.com    +1-555-777-8888
# 5          106      emma_watson         emma_watson@gmail  phone: 5556669999
# 6          107    Chris Brown     chris.brown@hotmail.com                N/A
# 7          108      mia   davis       mia.davis@gmail.com     (555)-000-1111
#
#            city                  review
# 0      new york       Great product!!!
# 1  LOS ANGELES           BAD service...
# 2   San   Diego   okay-quality, not bad
# 3       chicago     I LOVE this item!!!
# 4       HOUSTON       too expensive $$$
# 5    phoenix!!!      would buy again :)
# 6       Dallas?                     N/A
# 7     san jose   fast shipping--thanks!

# %% [markdown]
# Cleaning Texts
#
# There are many things that can be done to clean texts.

# %% [markdown]
# 1 Remove the Spaces at the beginning and the end

# %% [markdown]
# 2 Change text to lowercase

# %% [markdown]
# 3 Change text to title case

# %% [markdown]
# 4 Raplace characters

# %% [markdown]
# 5 Remove extra spaces inside text

# %% [markdown]
# 6 Remove punctuation or symbols

# %% [markdown]
# 7 Replace placeholder values with missing values

# %% [markdown]
# 8 Clean phone numbers

# %% [markdown]
# 9 Format phone number after cleaning

# %% [markdown]
# 10 Check whether text contains something

# %% [markdown]
# 11 Check if emails look valid

# %% [markdown]
# 12 Split text into new columns

# %% [markdown]
# 13 Extract text using regex

# %% [markdown]
# 14 Count text length

# %% [markdown]
# 15 Chain text cleaning steps together
